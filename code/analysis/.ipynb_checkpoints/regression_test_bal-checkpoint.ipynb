# %% [markdown]
# # Data Exploration: Land surface temperature in Baltimore

# %%
# import libraries
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# regression libraries
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble.partial_dependence import plot_partial_dependence
from sklearn.ensemble.partial_dependence import partial_dependence
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, median_absolute_error

RANDOM_SEED = 3201

# %%
# import data
df = pd.read_csv('../../data/data_regressions_500.csv')

# %% [markdown]
# # Describe

# %%
df.head()
# Out:
#    Unnamed: 0   alb_max  alb_max_sl  alb_mean  alb_mean_sl   alb_min  \
# 0           0  0.203087    0.378562  0.186376     0.268575  0.293390
# 1           1  0.175327    0.268992  0.174239     0.244864  0.316484
# 2           2  0.101527    0.161283  0.151535     0.235037  0.291655
# 3           3  0.098017    0.159679  0.181221     0.228555  0.298990
# 4           4  0.292987    0.137824  0.207661     0.228301  0.289621
#
#    alb_min_sl    alb_sd  alb_sd_sl      bldg      ...        tree_max  \
# 0    0.336449  0.101403   0.209058  0.398507      ...        0.260274
# 1    0.314011  0.076197   0.157516  0.302234      ...        0.260274
# 2    0.307773  0.046242   0.096056  0.302760      ...        0.273973
# 3    0.290650  0.043095   0.102312  0.360755      ...        0.260274
# 4    0.288823  0.104763   0.091791  0.261078      ...        0.260274
#
#   tree_max_sl  tree_mean  tree_mean_sl  tree_min  tree_min_sl   tree_sd  \
# 0    0.097819   0.043817      0.103620  0.243902      0.56338  0.098349
# 1    0.171589   0.036073      0.113462  0.243902      0.56338  0.090453
# 2    0.365981   0.031674      0.131563  0.243902      0.56338  0.074360
# 3    0.419813   0.041026      0.155007  0.243902      0.56338  0.057875
# 4    0.419813   0.083483      0.143806  0.243902      0.56338  0.189641
#
#    tree_sd_sl              x              y
# 0    0.043756  424996.178971  189212.211496
# 1    0.090479  425496.178971  189212.211496
# 2    0.161073  425996.178971  189212.211496
# 3    0.237982  426496.178971  189212.211496
# 4    0.204336  426996.178971  189212.211496
#
# [5 rows x 81 columns]

# %%
names = df.columns.values
names
# Out:
# array(['Unnamed: 0', 'alb_max', 'alb_max_sl', 'alb_mean', 'alb_mean_sl',
#        'alb_min', 'alb_min_sl', 'alb_sd', 'alb_sd_sl', 'bldg', 'bldg_sl',
#        'city', 'dsm_max', 'dsm_max_sl', 'dsm_mean', 'dsm_mean_sl',
#        'dsm_min', 'dsm_min_sl', 'dsm_sd', 'dsm_sd_sl', 'elev_max',
#        'elev_max_sl', 'elev_mean', 'elev_mean_sl', 'elev_min',
#        'elev_min_sl', 'elev_sd', 'elev_sd_sl', 'holdout', 'lcov_11',
#        'lcov_11_sl', 'lst_day_mean', 'lst_night_mean', 'nbdi_max',
#        'nbdi_max_sl', 'nbdi_mean', 'nbdi_mean_sl', 'nbdi_min',
#        'nbdi_min_sl', 'nbdi_sd', 'nbdi_sd_sl', 'ndvi_max', 'ndvi_max_sl',
#        'ndvi_mean', 'ndvi_mean_sl', 'ndvi_min', 'ndvi_min_sl', 'ndvi_sd',
#        'ndvi_sd_sl', 'ntl_max', 'ntl_max_sl', 'ntl_mean', 'ntl_mean_sl',
#        'ntl_min', 'ntl_min_sl', 'pdens_max', 'pdens_max_sl', 'pdens_mean',
#        'pdens_mean_sl', 'pdens_min', 'pdens_min_sl', 'pdens_sd',
#        'pdens_sd_sl', 'svf_max', 'svf_max_sl', 'svf_mean', 'svf_mean_sl',
#        'svf_min', 'svf_min_sl', 'svf_sd', 'svf_sd_sl', 'tree_max',
#        'tree_max_sl', 'tree_mean', 'tree_mean_sl', 'tree_min',
#        'tree_min_sl', 'tree_sd', 'tree_sd_sl', 'x', 'y'], dtype=object)

# %% [markdown]
# Remove the lat, long, name, cId columns and area == 0 rows

# %%
df = df.drop(['Unnamed: 0', 'x', 'y'], axis = 1)

# %%
# just baltimore for test
df = df[df['city'] == 'bal']

# %%
df.head()
# Out:
#     alb_max  alb_max_sl  alb_mean  alb_mean_sl   alb_min  alb_min_sl  \
# 0  0.203087    0.378562  0.186376     0.268575  0.293390    0.336449
# 1  0.175327    0.268992  0.174239     0.244864  0.316484    0.314011
# 2  0.101527    0.161283  0.151535     0.235037  0.291655    0.307773
# 3  0.098017    0.159679  0.181221     0.228555  0.298990    0.290650
# 4  0.292987    0.137824  0.207661     0.228301  0.289621    0.288823
#
#      alb_sd  alb_sd_sl      bldg   bldg_sl     ...        svf_sd  svf_sd_sl  \
# 0  0.101403   0.209058  0.398507  0.341111     ...      0.317177   0.305419
# 1  0.076197   0.157516  0.302234  0.310938     ...      0.255400   0.308460
# 2  0.046242   0.096056  0.302760  0.319941     ...      0.236328   0.319847
# 3  0.043095   0.102312  0.360755  0.282868     ...      0.280496   0.320153
# 4  0.104763   0.091791  0.261078  0.326049     ...      0.299707   0.322173
#
#    tree_max  tree_max_sl  tree_mean  tree_mean_sl  tree_min  tree_min_sl  \
# 0  0.260274     0.097819   0.043817      0.103620  0.243902      0.56338
# 1  0.260274     0.171589   0.036073      0.113462  0.243902      0.56338
# 2  0.273973     0.365981   0.031674      0.131563  0.243902      0.56338
# 3  0.260274     0.419813   0.041026      0.155007  0.243902      0.56338
# 4  0.260274     0.419813   0.083483      0.143806  0.243902      0.56338
#
#     tree_sd  tree_sd_sl
# 0  0.098349    0.043756
# 1  0.090453    0.090479
# 2  0.074360    0.161073
# 3  0.057875    0.237982
# 4  0.189641    0.204336
#
# [5 rows x 78 columns]

# %%
df.describe()
# Out:
#           alb_max  alb_max_sl    alb_mean  alb_mean_sl     alb_min  \
# count  744.000000  744.000000  744.000000   744.000000  744.000000
# mean     0.247928    0.300939    0.225669     0.319798    0.348025
# std      0.148622    0.139045    0.083628     0.099159    0.075843
# min      0.040584    0.057585    0.067681     0.133796    0.206460
# 25%      0.131779    0.188252    0.166382     0.251399    0.293058
# 50%      0.207885    0.271402    0.209060     0.298881    0.333677
# 75%      0.326601    0.400074    0.274614     0.388299    0.390807
# max      1.000000    0.759358    0.764914     0.628304    0.714519
#
#        alb_min_sl      alb_sd   alb_sd_sl        bldg     bldg_sl     ...      \
# count  744.000000  744.000000  744.000000  744.000000  744.000000     ...
# mean     0.372344    0.116333    0.194279    0.314152    0.379733     ...
# std      0.071202    0.084434    0.106308    0.180040    0.164721     ...
# min      0.242170    0.000000    0.034163    0.001749    0.000000     ...
# 25%      0.327149    0.061260    0.112433    0.196363    0.271655     ...
# 50%      0.361575    0.093564    0.166106    0.290126    0.353710     ...
# 75%      0.413260    0.147552    0.252256    0.399219    0.456678     ...
# max      0.575724    0.726988    0.679530    0.982017    1.000000     ...
#
#            svf_sd   svf_sd_sl    tree_max  tree_max_sl   tree_mean  \
# count  744.000000  744.000000  744.000000   744.000000  744.000000
# mean     0.290844    0.291397    0.206916     0.207240    0.066904
# std      0.109182    0.111854    0.261910     0.174485    0.050705
# min      0.070236    0.066463    0.000000     0.005607    0.012163
# 25%      0.223381    0.219447    0.027397     0.048598    0.039844
# 50%      0.268050    0.271054    0.027397     0.180374    0.052313
# 75%      0.332356    0.345685    0.287671     0.310748    0.065528
# max      0.946831    0.906639    1.000000     0.912150    0.452191
#
#        tree_mean_sl    tree_min  tree_min_sl     tree_sd  tree_sd_sl
# count    744.000000  744.000000   744.000000  744.000000  744.000000
# mean       0.146081    0.238395     0.536879    0.103304    0.123953
# std        0.046506    0.044345     0.078718    0.120496    0.103823
# min        0.030007    0.000000     0.070423    0.007025    0.000591
# 25%        0.118906    0.243902     0.563380    0.019278    0.037794
# 50%        0.133610    0.243902     0.563380    0.032798    0.098421
# 75%        0.152873    0.243902     0.563380    0.156173    0.195168
# max        0.328102    0.292683     0.626761    0.829805    0.539105
#
# [8 rows x 77 columns]

# %% [markdown]
# ## Response

# %%
plt.hist(df['lst_day_mean'], density = True, label = "diurnal", alpha = 0.5)
plt.hist(df['lst_night_mean'], density = True, label = "nocturnal", alpha = 0.5)
plt.legend(loc='upper right')
plt.title("Mean Baltimore Land Surface Temperature")
plt.show()

# %%
lst_vars = ['lst_day_mean','lst_night_mean']#, 'lst_day_min', 'lst_day_var', 'lst_day_max', 'lst_night_min', 'lst_night_max','lst_night_var']
df_lst = df[lst_vars]

# lst_vars_sl = [var + '_sl' for var in lst_vars]
df = df.drop(lst_vars, axis=1)
# df = df.drop(lst_vars_sl, axis=1)

# %% [markdown]
# # Divide into test and train

# %%
# remove city
df = df.drop('city', axis=1)
# remove holdout
df = df.drop('holdout', axis=1)
# identify non spatial lag terms
vars_sl = [x for x in df.columns if '_sl' in x]
vars_non_sl = [x for x in df.columns if '_sl' not in x]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df, df_lst, test_size=0.2, random_state=RANDOM_SEED)

# %% [markdown]
# ## Scale the variables

# %%
# make a copy
train = pd.concat([y_train.copy(), X_train.copy()], axis=1)
# train  = train.drop(['lst_day_mean_min', 'lst_day_mean_max', 'lst_night_mean_min', 'lst_night_mean_max'], axis=1)
train_nospatlag = train[vars_non_sl]
train.head()
# Out:
#      lst_day_mean  lst_night_mean   alb_max  alb_max_sl  alb_mean  \
# 297      2.036306        1.126490  0.247016    0.191279  0.218614
# 690      1.922745        1.933972  0.463054    0.495056  0.327495
# 372     -9.135828       -5.258926  0.104419    0.182333  0.085029
# 409      2.729519        1.498164  0.260970    0.321534  0.292839
# 53      -0.871967        0.076510  0.146234    0.201858  0.183291
#
#      alb_mean_sl   alb_min  alb_min_sl    alb_sd  alb_sd_sl     ...      \
# 297     0.317448  0.352659    0.399960  0.089099   0.114565     ...
# 690     0.485051  0.376571    0.279789  0.211402   0.411105     ...
# 372     0.166943  0.235981    0.264558  0.039675   0.110283     ...
# 409     0.388659  0.434357    0.420145  0.102366   0.211235     ...
# 53      0.285307  0.387323    0.399754  0.048392   0.093164     ...
#
#        svf_sd  svf_sd_sl  tree_max  tree_max_sl  tree_mean  tree_mean_sl  \
# 297  0.281412   0.241974  0.027397     0.041121   0.048964      0.115866
# 690  0.206249   0.344046  0.027397     0.013084   0.046868      0.079740
# 372  0.388718   0.363047  0.287671     0.306542   0.209279      0.255029
# 409  0.363744   0.390728  0.027397     0.044860   0.051591      0.114455
# 53   0.232514   0.206307  0.027397     0.104673   0.030380      0.105753
#
#      tree_min  tree_min_sl   tree_sd  tree_sd_sl
# 297  0.243902     0.492958  0.020740    0.032352
# 690  0.243902     0.077465  0.033271    0.111088
# 372  0.243902     0.563380  0.282942    0.261429
# 409  0.243902     0.429577  0.018062    0.047696
# 53   0.243902     0.563380  0.019134    0.029313
#
# [5 rows x 76 columns]

# %%
train.columns.values
# Out:
# array(['lst_day_mean', 'lst_night_mean', 'alb_max', 'alb_max_sl',
#        'alb_mean', 'alb_mean_sl', 'alb_min', 'alb_min_sl', 'alb_sd',
#        'alb_sd_sl', 'bldg', 'bldg_sl', 'city', 'dsm_max', 'dsm_max_sl',
#        'dsm_mean', 'dsm_mean_sl', 'dsm_min', 'dsm_min_sl', 'dsm_sd',
#        'dsm_sd_sl', 'elev_max', 'elev_max_sl', 'elev_mean',
#        'elev_mean_sl', 'elev_min', 'elev_min_sl', 'elev_sd', 'elev_sd_sl',
#        'holdout', 'lcov_11', 'lcov_11_sl', 'nbdi_max', 'nbdi_max_sl',
#        'nbdi_mean', 'nbdi_mean_sl', 'nbdi_min', 'nbdi_min_sl', 'nbdi_sd',
#        'nbdi_sd_sl', 'ndvi_max', 'ndvi_max_sl', 'ndvi_mean',
#        'ndvi_mean_sl', 'ndvi_min', 'ndvi_min_sl', 'ndvi_sd', 'ndvi_sd_sl',
#        'ntl_max', 'ntl_max_sl', 'ntl_mean', 'ntl_mean_sl', 'ntl_min',
#        'ntl_min_sl', 'pdens_max', 'pdens_max_sl', 'pdens_mean',
#        'pdens_mean_sl', 'pdens_min', 'pdens_min_sl', 'pdens_sd',
#        'pdens_sd_sl', 'svf_max', 'svf_max_sl', 'svf_mean', 'svf_mean_sl',
#        'svf_min', 'svf_min_sl', 'svf_sd', 'svf_sd_sl', 'tree_max',
#        'tree_max_sl', 'tree_mean', 'tree_mean_sl', 'tree_min',
#        'tree_min_sl', 'tree_sd', 'tree_sd_sl'], dtype=object)

# %% [markdown]
# # Explore correlations

# %% [markdown]
# ## Response

# %%
corr_matrix = df_lst.corr()
corr_matrix
# Out:
#                 lst_day_mean  lst_night_mean
# lst_day_mean        1.000000        0.922618
# lst_night_mean      0.922618        1.000000

# %% [markdown]
# ## All

# %%
corr_matrix = train_nospatlag.corr()
corr_matrix
# Out:
#              alb_max  alb_mean   alb_min    alb_sd      bldg   dsm_max  \
# alb_max     1.000000  0.730352  0.318563  0.908420  0.269518 -0.374421
# alb_mean    0.730352  1.000000  0.683535  0.725807  0.546587 -0.538661
# alb_min     0.318563  0.683535  1.000000  0.210272  0.542539 -0.400614
# alb_sd      0.908420  0.725807  0.210272  1.000000  0.171118 -0.385336
# bldg        0.269518  0.546587  0.542539  0.171118  1.000000 -0.071010
# dsm_max    -0.374421 -0.538661 -0.400614 -0.385336 -0.071010  1.000000
# dsm_mean   -0.425149 -0.603248 -0.415951 -0.436150 -0.159630  0.926035
# dsm_min    -0.392532 -0.543067 -0.354341 -0.409052 -0.137097  0.892619
# dsm_sd     -0.141054 -0.254635 -0.277315 -0.107757  0.015821  0.303030
# elev_max   -0.449540 -0.646090 -0.453932 -0.454383 -0.207657  0.921767
# elev_mean  -0.424193 -0.601705 -0.413116 -0.435806 -0.171137  0.918705
# elev_min   -0.390983 -0.542720 -0.355623 -0.408488 -0.132470  0.895484
# elev_sd    -0.271240 -0.476398 -0.414439 -0.233190 -0.300819  0.252295
# lcov_11     0.091311  0.069914 -0.165223  0.109875 -0.073189 -0.088539
# nbdi_max    0.562220  0.640965  0.352191  0.524936  0.303014 -0.448980
# nbdi_mean   0.554820  0.898286  0.710793  0.479157  0.664000 -0.490524
# nbdi_min    0.296211  0.616319  0.719686  0.200344  0.591108 -0.203171
# nbdi_sd     0.223941  0.050235 -0.289089  0.337237 -0.239929 -0.274907
# ndvi_max   -0.316768 -0.592998 -0.642958 -0.247438 -0.555745  0.209781
# ndvi_mean  -0.589105 -0.905365 -0.687710 -0.526424 -0.654614  0.488040
# ndvi_min   -0.630815 -0.698342 -0.392611 -0.586607 -0.365695  0.453205
# ndvi_sd     0.273947  0.111509 -0.211255  0.370603 -0.222465 -0.294181
# ntl_max     0.019029  0.029353  0.047588 -0.005674  0.084627  0.072202
# ntl_mean    0.019029  0.029353  0.047588 -0.005674  0.084627  0.072202
# ntl_min     0.019029  0.029353  0.047588 -0.005674  0.084627  0.072202
# pdens_max   0.092234  0.072866  0.080161  0.022475  0.141458 -0.009155
# pdens_mean -0.125815  0.166107  0.430485 -0.249234  0.639594  0.026298
# pdens_min  -0.125013 -0.145222 -0.051619 -0.147856 -0.010553  0.121399
# pdens_sd    0.076958  0.221211  0.287579 -0.018131  0.445079 -0.044538
# svf_max     0.311094  0.347626  0.222828  0.300033  0.029718 -0.355186
# svf_mean    0.194867  0.186894  0.080659  0.227944 -0.379318 -0.444567
# svf_min     0.018828  0.034063  0.115447  0.000219 -0.236880 -0.320182
# svf_sd     -0.039365 -0.058381 -0.085432 -0.039133  0.310613  0.339782
# tree_max   -0.160061 -0.378570 -0.472045 -0.070352 -0.442016  0.033120
# tree_mean  -0.087604 -0.317621 -0.327418 -0.050028 -0.314505  0.095446
# tree_min   -0.059052 -0.002474  0.268568 -0.070012  0.122795  0.071382
# tree_sd    -0.200281 -0.484024 -0.555250 -0.113234 -0.501677  0.121902
#
#             dsm_mean   dsm_min    dsm_sd  elev_max    ...     pdens_min  \
# alb_max    -0.425149 -0.392532 -0.141054 -0.449540    ...     -0.125013
# alb_mean   -0.603248 -0.543067 -0.254635 -0.646090    ...     -0.145222
# alb_min    -0.415951 -0.354341 -0.277315 -0.453932    ...     -0.051619
# alb_sd     -0.436150 -0.409052 -0.107757 -0.454383    ...     -0.147856
# bldg       -0.159630 -0.137097  0.015821 -0.207657    ...     -0.010553
# dsm_max     0.926035  0.892619  0.303030  0.921767    ...      0.121399
# dsm_mean    1.000000  0.984091  0.102956  0.991106    ...      0.146675
# dsm_min     0.984091  1.000000 -0.032004  0.963852    ...      0.153663
# dsm_sd      0.102956 -0.032004  1.000000  0.172118    ...     -0.012801
# elev_max    0.991106  0.963852  0.172118  1.000000    ...      0.151279
# elev_mean   0.999329  0.986316  0.078819  0.990703    ...      0.147930
# elev_min    0.985765  0.999084 -0.026123  0.965675    ...      0.153549
# elev_sd     0.187508  0.041551  0.797821  0.290825    ...      0.011835
# lcov_11    -0.118180 -0.107363 -0.026902 -0.124192    ...     -0.029510
# nbdi_max   -0.496256 -0.455306 -0.166653 -0.518075    ...     -0.210681
# nbdi_mean  -0.550177 -0.482051 -0.279678 -0.600622    ...     -0.129602
# nbdi_min   -0.263623 -0.205442 -0.168934 -0.314970    ...     -0.012406
# nbdi_sd    -0.273935 -0.291972 -0.002154 -0.243247    ...     -0.166662
# ndvi_max    0.279837  0.233229  0.114087  0.327019    ...      0.013923
# ndvi_mean   0.565770  0.503402  0.226965  0.614742    ...      0.130601
# ndvi_min    0.529344  0.487397  0.151230  0.554024    ...      0.195476
# ndvi_sd    -0.293026 -0.295629 -0.063277 -0.267837    ...     -0.172613
# ntl_max     0.068508  0.063792  0.033021  0.070053    ...      0.012969
# ntl_mean    0.068508  0.063792  0.033021  0.070053    ...      0.012969
# ntl_min     0.068508  0.063792  0.033021  0.070053    ...      0.012969
# pdens_max  -0.030145 -0.028860  0.013253 -0.037858    ...     -0.025822
# pdens_mean  0.013692  0.021983 -0.022075 -0.004746    ...      0.035495
# pdens_min   0.146675  0.153663 -0.012801  0.151279    ...      1.000000
# pdens_sd   -0.119574 -0.125462  0.108450 -0.135508    ...     -0.086691
# svf_max    -0.273582 -0.219980 -0.454923 -0.303343    ...     -0.090960
# svf_mean   -0.265741 -0.191277 -0.664593 -0.256932    ...     -0.016729
# svf_min    -0.128830 -0.059234 -0.547032 -0.123500    ...      0.094458
# svf_sd      0.140798  0.064778  0.651037  0.131166    ...     -0.068081
# tree_max    0.050773  0.012473  0.140604  0.088840    ...     -0.070241
# tree_mean   0.045835 -0.038746  0.430041  0.097299    ...     -0.098144
# tree_min    0.078870  0.075254  0.020383  0.077976    ...      0.031877
# tree_sd     0.118929  0.060781  0.250762  0.166538    ...     -0.078839
#
#             pdens_sd   svf_max  svf_mean   svf_min    svf_sd  tree_max  \
# alb_max     0.076958  0.311094  0.194867  0.018828 -0.039365 -0.160061
# alb_mean    0.221211  0.347626  0.186894  0.034063 -0.058381 -0.378570
# alb_min     0.287579  0.222828  0.080659  0.115447 -0.085432 -0.472045
# alb_sd     -0.018131  0.300033  0.227944  0.000219 -0.039133 -0.070352
# bldg        0.445079  0.029718 -0.379318 -0.236880  0.310613 -0.442016
# dsm_max    -0.044538 -0.355186 -0.444567 -0.320182  0.339782  0.033120
# dsm_mean   -0.119574 -0.273582 -0.265741 -0.128830  0.140798  0.050773
# dsm_min    -0.125462 -0.219980 -0.191277 -0.059234  0.064778  0.012473
# dsm_sd      0.108450 -0.454923 -0.664593 -0.547032  0.651037  0.140604
# elev_max   -0.135508 -0.303343 -0.256932 -0.123500  0.131166  0.088840
# elev_mean  -0.127360 -0.260758 -0.233975 -0.104172  0.109693  0.048585
# elev_min   -0.125113 -0.220739 -0.195966 -0.065684  0.069914  0.010018
# elev_sd    -0.049729 -0.356113 -0.256415 -0.217841  0.233178  0.276660
# lcov_11    -0.062025  0.040472  0.103625 -0.023311 -0.036634  0.025583
# nbdi_max    0.129333  0.375131  0.226253  0.063647 -0.081589 -0.194550
# nbdi_mean   0.312349  0.325375  0.103437  0.029814 -0.036831 -0.469716
# nbdi_min    0.216534  0.115524 -0.099476 -0.069019  0.095434 -0.497322
# nbdi_sd    -0.089898  0.247881  0.307368  0.087192 -0.162082  0.348025
# ndvi_max   -0.177458 -0.090836  0.133983  0.120910 -0.147926  0.402241
# ndvi_mean  -0.297617 -0.295633 -0.049817  0.028456 -0.029467  0.444021
# ndvi_min   -0.195182 -0.363020 -0.167114  0.003347  0.021383  0.217179
# ndvi_sd    -0.069909  0.284304  0.363323  0.129590 -0.215970  0.235881
# ntl_max     0.057114 -0.035801 -0.066775 -0.025119  0.052126 -0.156963
# ntl_mean    0.057114 -0.035801 -0.066775 -0.025119  0.052126 -0.156963
# ntl_min     0.057114 -0.035801 -0.066775 -0.025119  0.052126 -0.156963
# pdens_max   0.733620  0.005506 -0.083463 -0.046198  0.069364 -0.053121
# pdens_mean  0.653306 -0.056692 -0.310333 -0.101688  0.145613 -0.299587
# pdens_min  -0.086691 -0.090960 -0.016729  0.094458 -0.068081 -0.070241
# pdens_sd    1.000000 -0.045596 -0.320576 -0.232539  0.288104 -0.156528
# svf_max    -0.045596  1.000000  0.487631  0.357199 -0.415512 -0.140957
# svf_mean   -0.320576  0.487631  1.000000  0.705109 -0.893176  0.023035
# svf_min    -0.232539  0.357199  0.705109  1.000000 -0.869404 -0.030940
# svf_sd      0.288104 -0.415512 -0.893176 -0.869404  1.000000  0.010610
# tree_max   -0.156528 -0.140957  0.023035 -0.030940  0.010610  1.000000
# tree_mean  -0.131318 -0.168307 -0.234099 -0.240127  0.297842  0.517920
# tree_min    0.091783 -0.056754 -0.128432 -0.006715  0.062748 -0.054023
# tree_sd    -0.205012 -0.178117 -0.069291 -0.112899  0.111415  0.866339
#
#             tree_mean  tree_min   tree_sd
# alb_max     -0.087604 -0.059052 -0.200281
# alb_mean    -0.317621 -0.002474 -0.484024
# alb_min     -0.327418  0.268568 -0.555250
# alb_sd      -0.050028 -0.070012 -0.113234
# bldg        -0.314505  0.122795 -0.501677
# dsm_max      0.095446  0.071382  0.121902
# dsm_mean     0.045835  0.078870  0.118929
# dsm_min     -0.038746  0.075254  0.060781
# dsm_sd       0.430041  0.020383  0.250762
# elev_max     0.097299  0.077976  0.166538
# elev_mean    0.030799  0.075425  0.112494
# elev_min    -0.037734  0.076264  0.059652
# elev_sd      0.497502  0.012413  0.393706
# lcov_11     -0.059707 -0.713619  0.077785
# nbdi_max    -0.200303 -0.042711 -0.282297
# nbdi_mean   -0.405304 -0.022098 -0.580130
# nbdi_min    -0.325374  0.008768 -0.548332
# nbdi_sd      0.150257 -0.059317  0.322744
# ndvi_max     0.227632 -0.013228  0.439494
# ndvi_mean    0.339716  0.029983  0.535850
# ndvi_min     0.213847  0.151626  0.299360
# ndvi_sd      0.025989 -0.090520  0.194997
# ntl_max     -0.119113 -0.007116 -0.173058
# ntl_mean    -0.119113 -0.007116 -0.173058
# ntl_min     -0.119113 -0.007116 -0.173058
# pdens_max   -0.049376  0.028858 -0.076783
# pdens_mean  -0.250026  0.147491 -0.349430
# pdens_min   -0.098144  0.031877 -0.078839
# pdens_sd    -0.131318  0.091783 -0.205012
# svf_max     -0.168307 -0.056754 -0.178117
# svf_mean    -0.234099 -0.128432 -0.069291
# svf_min     -0.240127 -0.006715 -0.112899
# svf_sd       0.297842  0.062748  0.111415
# tree_max     0.517920 -0.054023  0.866339
# tree_mean    1.000000  0.045918  0.764745
# tree_min     0.045918  1.000000 -0.093682
# tree_sd      0.764745 -0.093682  1.000000
#
# [37 rows x 37 columns]

# %%
plt.figure(figsize=(15,10))
sns.heatmap(corr_matrix, cmap='PiYG',
            xticklabels=corr_matrix.columns,
            yticklabels=corr_matrix.columns,
            vmin=-0.8,vmax=0.8,center=0)

# %%
train_nospatlag.hist(bins = 30, figsize=(20,15), density = True)
plt.show()

# %% [markdown]
# # Scatter

# %%
# list the covariates
covariates = list(train_nospatlag.columns)

# %% [markdown]
# ## Response

# %%
plt.scatter(train['lst_day_mean'], train['lst_night_mean'])
plt.title("Diurnal vs Nocturnal LST in Baltimore")
plt.xlabel('Diurnal')
plt.ylabel('Nocturnal')
plt.show()

# %% [markdown]
# ## Response-covariate

# %%
for covar in covariates:
    # plot each scatter
    plt.scatter(train[covar], train['lst_day_mean'], label = 'Diurnal', alpha = 0.5)
    plt.scatter(train[covar], train['lst_night_mean'], label = 'Nocturnal', alpha = 0.5)
    plt.xlabel(covar)
    plt.ylabel('LST')
    plt.legend(loc='upper right')
    plt.show()
    
# Note: lcov variables are defined here: https://www.mrlc.gov/nlcd11_leg.php

# %% [markdown]
# # Initial Regressions

# %% [markdown]
# Doing some initial regression fitting to see how the models look and what the most important variables are.

# %%
# X_train, lst_day_train, lst_night_train, X_test
lst_day_train = y_train['lst_day_mean']
lst_night_train = y_train['lst_night_mean']
# test
lst_day_test = y_test['lst_day_mean']
lst_night_test = y_test['lst_night_mean']

# %% [markdown]
# ### Null

# %%
# train the model

# predict the model
null_predict_day = np.ones(len(lst_day_test)) * np.mean(lst_day_train)
null_predict_night = np.ones(len(lst_night_test)) * np.mean(lst_night_train)
xy_line = (np.min([lst_day_test,lst_night_test]),np.max([lst_day_test,lst_night_test]))

# plot predict vs actual
plt.scatter(lst_day_test, null_predict_day, label = 'Diurnal')
plt.scatter(lst_night_test, null_predict_night, label = 'Nocturnal')
plt.plot(xy_line,xy_line, 'k--')
plt.ylabel('Predicted')
plt.xlabel('Actual')
plt.legend(loc='upper right')
plt.show()

# calculate the MAE
r2_day = r2_score(lst_day_test, null_predict_day)
r2_night = r2_score(lst_night_test, null_predict_night)
print('Diurnal variance score: {0:.2f}'.format(r2_day))
print('Nocturnal variance score: {0:.2f}'.format(r2_night))
# Out:
# Diurnal variance score: -0.00
# Nocturnal variance score: -0.01

# %% [markdown]
# ### MLR

# %%
# train the model
mlr_day_reg = LinearRegression()
mlr_night_reg = LinearRegression()
mlr_day_reg.fit(X_train, lst_day_train)
mlr_night_reg.fit(X_train, lst_night_train)
xy_line = (np.min([lst_day_test,lst_night_test]),np.max([lst_day_test,lst_night_test]))

# predict the model
mlr_predict_day = mlr_day_reg.predict(X_test)
mlr_predict_night = mlr_night_reg.predict(X_test)

# plot predict vs actual
plt.scatter(lst_day_test, mlr_predict_day, label = 'Diurnal')
plt.scatter(lst_night_test, mlr_predict_night, label = 'Nocturnal')
plt.plot(xy_line,xy_line, 'k--')
plt.ylabel('Predicted')
plt.xlabel('Actual')
plt.legend(loc='upper right')
plt.show()

# calculate the OOB R2
r2_day = r2_score(lst_day_test, mlr_predict_day)
r2_night = r2_score(lst_night_test, mlr_predict_night)
print('Diurnal variance score: {0:.2f}'.format(r2_day))
print('Nocturnal variance score: {0:.2f}'.format(r2_night))
# Out:
# Diurnal variance score: 0.97
# Nocturnal variance score: 0.97

# %%
mlr_coeffs = pd.DataFrame(list(zip(X_train.columns, mlr_day_reg.coef_,mlr_night_reg.coef_))b, columns = ['features','day','night'])

# %%
mlr_coeffs
# Out:
#          features           day         night
# 0         alb_max -1.776003e-01  1.245276e-01
# 1      alb_max_sl -7.081160e-01 -1.388590e+00
# 2        alb_mean -7.724560e+00 -7.539779e-01
# 3     alb_mean_sl -1.671271e+00  9.092519e-01
# 4         alb_min -1.155243e-01  7.578988e-01
# 5      alb_min_sl -3.398826e+00  6.775037e-01
# 6          alb_sd  1.826595e+00 -1.467002e+00
# 7       alb_sd_sl  2.509045e+00 -1.169889e-01
# 8            bldg  3.316317e+00 -6.312625e-01
# 9         bldg_sl  9.793475e-01  5.773856e-01
# 10        dsm_max -1.174435e+00 -4.326345e-02
# 11     dsm_max_sl -1.990692e+00 -7.527845e-01
# 12       dsm_mean -4.663060e+01 -4.357816e+01
# 13    dsm_mean_sl -3.010727e+01 -2.927863e+01
# 14        dsm_min -5.094826e+00  1.189163e+00
# 15     dsm_min_sl -1.069610e+01  5.609795e+00
# 16         dsm_sd  1.035533e+01  5.671748e+00
# 17      dsm_sd_sl  3.538181e-01  4.430216e+00
# 18       elev_max  1.739978e+00  1.993212e+00
# 19    elev_max_sl  3.842750e-01 -7.818726e+00
# 20      elev_mean  4.472586e+01  4.538555e+01
# 21   elev_mean_sl  3.232049e+01  3.608811e+01
# 22       elev_min  3.204819e+00 -1.579522e+00
# 23    elev_min_sl  9.577599e+00 -1.105799e+01
# 24        elev_sd -9.829262e+00 -5.783676e+00
# 25     elev_sd_sl -3.257040e+00 -6.384280e+00
# 26        lcov_11 -6.533022e+00 -4.374599e+00
# 27     lcov_11_sl  1.158133e+00  1.481898e+00
# 28       nbdi_max -5.772467e-01 -4.381130e-01
# 29    nbdi_max_sl -1.153069e+00 -3.065831e-01
# ..            ...           ...           ...
# 44        ntl_max  3.032881e+12  2.017297e+12
# 45     ntl_max_sl -1.131388e+12  1.133487e+12
# 46       ntl_mean -8.658776e+11  9.516000e+11
# 47    ntl_mean_sl -2.711345e+12 -6.367608e+12
# 48        ntl_min  1.254515e+12  7.144359e+11
# 49     ntl_min_sl  7.440224e+11  1.747340e+12
# 50      pdens_max  1.410767e-01 -2.948541e-01
# 51   pdens_max_sl -5.851284e-01 -6.508095e-01
# 52     pdens_mean  1.129130e+00  8.346906e-02
# 53  pdens_mean_sl  2.625618e-01 -4.060514e-01
# 54      pdens_min -4.237483e-01  1.442302e-01
# 55   pdens_min_sl  7.101504e-02  4.193481e-01
# 56       pdens_sd  1.385050e-01  8.225524e-01
# 57    pdens_sd_sl  6.348172e-01  9.329674e-01
# 58        svf_max  1.729941e+00  1.023795e-01
# 59     svf_max_sl  3.185016e+00  8.607542e-01
# 60       svf_mean  7.452594e+00 -4.028844e-01
# 61    svf_mean_sl -5.403524e+00 -1.336047e+00
# 62        svf_min -1.755763e-01 -1.310456e-01
# 63     svf_min_sl -8.883940e-01 -1.011037e+00
# 64         svf_sd -7.817295e-01 -6.666872e-01
# 65      svf_sd_sl -1.891980e+00 -1.756209e+00
# 66       tree_max -6.774277e-01 -5.981322e-01
# 67    tree_max_sl  9.602754e-01  4.846903e-01
# 68      tree_mean -2.370879e+01 -1.965202e+01
# 69   tree_mean_sl  5.774131e+00  1.349016e+00
# 70       tree_min  6.642110e-01 -1.962275e+00
# 71    tree_min_sl  1.243327e+00  2.766094e-01
# 72        tree_sd  4.009665e+00  3.341578e+00
# 73     tree_sd_sl -2.908983e+00 -1.566385e+00
#
# [74 rows x 3 columns]

# %% [markdown]
# ### Random Forest

# %%
# train the model
rf_day_reg = RandomForestRegressor(max_depth=2, random_state=RANDOM_SEED, n_estimators=500, max_features=1/3)
rf_night_reg = RandomForestRegressor(max_depth=2, random_state=RANDOM_SEED, n_estimators=500, max_features=1/3)
rf_day_reg.fit(X_train, lst_day_train)
rf_night_reg.fit(X_train, lst_night_train)
xy_line = (np.min([lst_day_test,lst_night_test]),np.max([lst_day_test,lst_night_test]))

# predict the model
rf_predict_day = rf_day_reg.predict(X_test)
rf_predict_night = rf_night_reg.predict(X_test)

# plot predict vs actual
plt.scatter(lst_day_test, rf_predict_day, label = 'Diurnal')
plt.scatter(lst_night_test, rf_predict_night, label = 'Nocturnal')
plt.plot(xy_line,xy_line, 'k--')
plt.ylabel('Predicted')
plt.xlabel('Actual')
plt.legend(loc='upper right')
plt.show()

# calculate the MAE
# mae_day = np.mean(abs(rf_predict_day - lst_day_test))
# mae_night = np.mean(abs(rf_predict_night - lst_night_test))
# print('Nocturnal MAE: {}'.format(mae_night))
# print('Diurnal MAE: {}'.format(mae_day))

# calculate the OOB R2
r2_day = r2_score(lst_day_test, rf_predict_day)
r2_night = r2_score(lst_night_test, rf_predict_night)
print('Diurnal variance score: {0:.2f}'.format(r2_day))
print('Nocturnal variance score: {0:.2f}'.format(r2_night))
# Out:
# Diurnal variance score: 0.89
# Nocturnal variance score: 0.87

# %% [markdown]
# #### Variable importance

# %%
important_num = 5 # top five
importances = rf_night_reg.feature_importances_
covariates = X_train.columns

indices = np.argsort(importances)[::-1]

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importance: Night")
plt.bar(range(important_num), importances[indices[0:important_num]],
       color="b", align="center")
plt.xticks(range(important_num), covariates[indices[0:important_num]], rotation=90)
plt.xlim([-1, important_num])
plt.show()

# Print the feature ranking
print("Feature ranking:")

for f in range(len(indices)): 
    print("{}. {} ({})".format(f + 1, covariates[indices[f]], importances[indices[f]]))
# Out:
# Feature ranking:
# 1. tree_mean (0.2505826880474446)
# 2. nbdi_mean (0.22755612073306314)
# 3. tree_sd (0.10337751734389526)
# 4. alb_mean (0.08853924208344933)
# 5. ndvi_mean (0.0877565589659289)
# 6. nbdi_mean_sl (0.06895739393724394)
# 7. ndvi_mean_sl (0.05821892628692827)
# 8. alb_min (0.01940365996955689)
# 9. alb_mean_sl (0.016566035409670363)
# 10. tree_mean_sl (0.01626324176210227)
# 11. alb_min_sl (0.013858209204861685)
# 12. nbdi_min_sl (0.00706868272129561)
# 13. tree_sd_sl (0.006120643297914039)
# 14. ndvi_min_sl (0.005396727447374341)
# 15. svf_sd (0.004723822932476507)
# 16. tree_max (0.004566912490599951)
# 17. elev_sd (0.003890000131428278)
# 18. dsm_sd (0.0028552931103153194)
# 19. svf_mean (0.0026765951024284376)
# 20. dsm_sd_sl (0.0017496555659116733)
# 21. ndvi_max_sl (0.0016051753099398714)
# 22. elev_mean_sl (0.0009011862935214084)
# 23. svf_min_sl (0.0008925073345822383)
# 24. elev_sd_sl (0.0008917770783967579)
# 25. elev_max_sl (0.0008509358608690742)
# 26. pdens_mean (0.0007332832431617483)
# 27. bldg (0.0007212822628412172)
# 28. tree_max_sl (0.000599964754481838)
# 29. elev_max (0.0005448742820265573)
# 30. dsm_mean_sl (0.0005325596090931323)
# 31. svf_max_sl (0.0003370337898187716)
# 32. ndvi_max (0.00026089699080778547)
# 33. ndvi_min (0.0002590932227461809)
# 34. elev_mean (0.00025573668578319673)
# 35. svf_min (0.00020159686671826377)
# 36. nbdi_sd (0.0001955503138861885)
# 37. nbdi_min (8.861955743697413e-05)
# 38. alb_max_sl (0.0)
# 39. dsm_max_sl (0.0)
# 40. pdens_sd (0.0)
# 41. pdens_sd_sl (0.0)
# 42. dsm_min_sl (0.0)
# 43. dsm_min (0.0)
# 44. svf_max (0.0)
# 45. dsm_mean (0.0)
# 46. bldg_sl (0.0)
# 47. dsm_max (0.0)
# 48. tree_min_sl (0.0)
# 49. pdens_min_sl (0.0)
# 50. alb_sd_sl (0.0)
# 51. alb_sd (0.0)
# 52. svf_sd_sl (0.0)
# 53. tree_min (0.0)
# 54. svf_mean_sl (0.0)
# 55. ndvi_sd (0.0)
# 56. pdens_min (0.0)
# 57. ntl_min_sl (0.0)
# 58. ndvi_sd_sl (0.0)
# 59. ntl_max (0.0)
# 60. ntl_max_sl (0.0)
# 61. ntl_mean (0.0)
# 62. nbdi_sd_sl (0.0)
# 63. ntl_mean_sl (0.0)
# 64. ntl_min (0.0)
# 65. nbdi_max_sl (0.0)
# 66. pdens_mean_sl (0.0)
# 67. nbdi_max (0.0)
# 68. lcov_11_sl (0.0)
# 69. lcov_11 (0.0)
# 70. pdens_max (0.0)
# 71. pdens_max_sl (0.0)
# 72. elev_min_sl (0.0)
# 73. elev_min (0.0)
# 74. alb_max (0.0)

# %%
important_num = 5 # top five
importances = rf_day_reg.feature_importances_
covariates = X_train.columns

indices = np.argsort(importances)[::-1]

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importance: Day")
plt.bar(range(important_num), importances[indices[0:important_num]],
       color="r", align="center")
plt.xticks(range(important_num), covariates[indices[0:important_num]], rotation=90)
plt.xlim([-1, important_num])
plt.show()

# Print the feature ranking
print("Feature ranking:")

for f in range(len(indices)): 
    print("{}. {} ({})".format(f + 1, covariates[indices[f]], importances[indices[f]]))
# Out:
# Feature ranking:
# 1. nbdi_mean (0.3463503215102122)
# 2. ndvi_mean (0.20114392128209208)
# 3. tree_mean (0.11571740199308342)
# 4. alb_mean (0.11330115091191577)
# 5. tree_sd (0.06495862869589909)
# 6. nbdi_mean_sl (0.04228158488741223)
# 7. ndvi_mean_sl (0.024172329025400747)
# 8. bldg (0.019041048533398747)
# 9. tree_max (0.010724985177598073)
# 10. tree_sd_sl (0.009582717088767503)
# 11. alb_min (0.009412983141572571)
# 12. bldg_sl (0.008943559572309485)
# 13. alb_mean_sl (0.006934612427646095)
# 14. svf_sd (0.00572654093015084)
# 15. alb_min_sl (0.004547267551836144)
# 16. tree_mean_sl (0.0039144547160043786)
# 17. svf_mean (0.0020657073094753364)
# 18. ndvi_min_sl (0.0018618245688489176)
# 19. dsm_sd (0.0018266088899656404)
# 20. nbdi_min_sl (0.0015286387561257715)
# 21. elev_sd (0.0015115558823593808)
# 22. dsm_sd_sl (0.0008546709083276091)
# 23. pdens_mean (0.0007437092637535361)
# 24. elev_sd_sl (0.0006805457052192989)
# 25. alb_max_sl (0.0004177691121533795)
# 26. nbdi_min (0.000284907328526239)
# 27. elev_max_sl (0.0002583553407202762)
# 28. alb_sd (0.00024692486380334394)
# 29. tree_max_sl (0.00022463411434199272)
# 30. nbdi_sd (0.0002217244544027095)
# 31. svf_min_sl (0.00020784610216227045)
# 32. pdens_mean_sl (0.0001361340661007722)
# 33. ndvi_sd (8.758817489704542e-05)
# 34. ndvi_min (8.734771351685621e-05)
# 35. dsm_min (0.0)
# 36. elev_min (0.0)
# 37. elev_min_sl (0.0)
# 38. dsm_max (0.0)
# 39. alb_sd_sl (0.0)
# 40. elev_mean_sl (0.0)
# 41. dsm_min_sl (0.0)
# 42. dsm_max_sl (0.0)
# 43. elev_mean (0.0)
# 44. elev_max (0.0)
# 45. dsm_mean (0.0)
# 46. lcov_11 (0.0)
# 47. dsm_mean_sl (0.0)
# 48. ndvi_max (0.0)
# 49. lcov_11_sl (0.0)
# 50. nbdi_max (0.0)
# 51. tree_min_sl (0.0)
# 52. tree_min (0.0)
# 53. svf_sd_sl (0.0)
# 54. svf_min (0.0)
# 55. svf_mean_sl (0.0)
# 56. svf_max_sl (0.0)
# 57. svf_max (0.0)
# 58. pdens_sd_sl (0.0)
# 59. pdens_sd (0.0)
# 60. pdens_min_sl (0.0)
# 61. pdens_min (0.0)
# 62. pdens_max_sl (0.0)
# 63. pdens_max (0.0)
# 64. ntl_min_sl (0.0)
# 65. ntl_min (0.0)
# 66. ntl_mean_sl (0.0)
# 67. ntl_mean (0.0)
# 68. ntl_max_sl (0.0)
# 69. ntl_max (0.0)
# 70. ndvi_sd_sl (0.0)
# 71. ndvi_max_sl (0.0)
# 72. nbdi_sd_sl (0.0)
# 73. nbdi_max_sl (0.0)
# 74. alb_max (0.0)

# %% [markdown]
# Note:
# * lcov_11 is the area of water in the grid cell
# * lcov_23 is the area of developed, medium intensity in the cell (single-family housing units)
# * alb = albedo
# * tree = tree canopy
# * imp = impervious surface
# * the _mean / _min / _max are the mean, min, or max of measurements within the cell from the averaged satellite images
# * _sl means the average of the surrounding cells (i.e. spatially lagged variable)

# %% [markdown]
# ### Gradient Boosted Regression Trees

# %%
# train the model
gbm_day_reg = GradientBoostingRegressor(max_depth=2, random_state=RANDOM_SEED, learning_rate=0.1, n_estimators=500, loss='ls')
gbm_night_reg = GradientBoostingRegressor(max_depth=2, random_state=RANDOM_SEED, learning_rate=0.1, n_estimators=500, loss='ls')
gbm_day_reg.fit(X_train, lst_day_train)
gbm_night_reg.fit(X_train, lst_night_train)

# predict the model
gbm_predict_day = gbm_day_reg.predict(X_test)
gbm_predict_night = gbm_night_reg.predict(X_test)
xy_line = (np.min([lst_day_test,lst_night_test]),np.max([lst_day_test,lst_night_test]))

# plot predict vs actual
plt.scatter(lst_day_test, gbm_predict_day, label = 'Diurnal')
plt.scatter(lst_night_test, gbm_predict_night, label = 'Nocturnal')
plt.plot(xy_line,xy_line, 'k--')
plt.ylabel('Predicted')
plt.xlabel('Actual')
plt.legend(loc='upper right')
plt.show()

# calculate the MAE
r2_day = r2_score(lst_day_test, gbm_predict_day)
r2_night = r2_score(lst_night_test, gbm_predict_night)
print('Diurnal variance score: {0:.2f}'.format(r2_day))
print('Nocturnal variance score: {0:.2f}'.format(r2_night))
# Out:
# Diurnal variance score: 0.97
# Nocturnal variance score: 0.97

# %% [markdown]
# ### Variable Importance

# %%
important_num = 5 # top five
importances = gbm_night_reg.feature_importances_
covariates = X_train.columns

indices = np.argsort(importances)[::-1]

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importance: Night")
plt.bar(range(important_num), importances[indices[0:important_num]],
       color="b", align="center")
plt.xticks(range(important_num), covariates[indices[0:important_num]], rotation=90)
plt.xlim([-1, important_num])
plt.show()

# Print the feature ranking
print("Feature ranking:")

for f in range(len(indices)): 
    print("{}. feature #{}: {} ({})".format(f + 1,indices[f], covariates[indices[f]], importances[indices[f]]))
# Out:
# Feature ranking:
# 1. feature #68: tree_mean (0.0643547581987709)
# 2. feature #72: tree_sd (0.03109402799427844)
# 3. feature #64: svf_sd (0.02646615511662713)
# 4. feature #8: bldg (0.026153114813938873)
# 5. feature #28: nbdi_max (0.02587713745488638)
# 6. feature #7: alb_sd_sl (0.025641178303158915)
# 7. feature #36: ndvi_max (0.024819347519016235)
# 8. feature #1: alb_max_sl (0.02477326495861479)
# 9. feature #59: svf_max_sl (0.022818374993502838)
# 10. feature #38: ndvi_mean (0.022581652736118858)
# 11. feature #58: svf_max (0.022442710968254488)
# 12. feature #29: nbdi_max_sl (0.02231232249170281)
# 13. feature #5: alb_min_sl (0.02228100224332833)
# 14. feature #61: svf_mean_sl (0.021840812114836995)
# 15. feature #50: pdens_max (0.021121164023516287)
# 16. feature #25: elev_sd_sl (0.02099992324240517)
# 17. feature #6: alb_sd (0.02073010516163638)
# 18. feature #34: nbdi_sd (0.02060645558275932)
# 19. feature #40: ndvi_min (0.020319203318914295)
# 20. feature #52: pdens_mean (0.020038407497676936)
# 21. feature #10: dsm_max (0.019845684028796693)
# 22. feature #32: nbdi_min (0.018833738575286623)
# 23. feature #9: bldg_sl (0.018656814693924027)
# 24. feature #53: pdens_mean_sl (0.018167196290361835)
# 25. feature #26: lcov_11 (0.017706714564948392)
# 26. feature #4: alb_min (0.017106764897234884)
# 27. feature #35: nbdi_sd_sl (0.01705819385920195)
# 28. feature #43: ndvi_sd_sl (0.01681111803661566)
# 29. feature #30: nbdi_mean (0.0165669733077555)
# 30. feature #67: tree_max_sl (0.0164465948693113)
# 31. feature #18: elev_max (0.01582654303790845)
# 32. feature #62: svf_min (0.015129172224023818)
# 33. feature #0: alb_max (0.01455069446819077)
# 34. feature #60: svf_mean (0.014179607016041571)
# 35. feature #56: pdens_sd (0.013938625241127111)
# 36. feature #17: dsm_sd_sl (0.013145328196989825)
# 37. feature #42: ndvi_sd (0.013082772774981507)
# 38. feature #19: elev_max_sl (0.012512410427584025)
# 39. feature #11: dsm_max_sl (0.012338677511020593)
# 40. feature #57: pdens_sd_sl (0.012337127871860115)
# 41. feature #22: elev_min (0.012102093683350522)
# 42. feature #37: ndvi_max_sl (0.011839882365382838)
# 43. feature #3: alb_mean_sl (0.011559817850987046)
# 44. feature #2: alb_mean (0.011188389933993258)
# 45. feature #41: ndvi_min_sl (0.01045856837590235)
# 46. feature #31: nbdi_mean_sl (0.009551152756358115)
# 47. feature #23: elev_min_sl (0.009250858784717809)
# 48. feature #65: svf_sd_sl (0.008522462194450882)
# 49. feature #14: dsm_min (0.008195824407952414)
# 50. feature #51: pdens_max_sl (0.007779254763333247)
# 51. feature #73: tree_sd_sl (0.0075368061295584135)
# 52. feature #33: nbdi_min_sl (0.0073776679129214165)
# 53. feature #69: tree_mean_sl (0.006793910574747485)
# 54. feature #63: svf_min_sl (0.006516666815516295)
# 55. feature #24: elev_sd (0.006450224450387659)
# 56. feature #12: dsm_mean (0.0054099365849638445)
# 57. feature #39: ndvi_mean_sl (0.005207986086064306)
# 58. feature #16: dsm_sd (0.004626446224491502)
# 59. feature #70: tree_min (0.004225706855749275)
# 60. feature #20: elev_mean (0.0041936220481593855)
# 61. feature #13: dsm_mean_sl (0.0041402589197885925)
# 62. feature #66: tree_max (0.0037057370309986773)
# 63. feature #55: pdens_min_sl (0.003269100931489065)
# 64. feature #71: tree_min_sl (0.002737019857492277)
# 65. feature #21: elev_mean_sl (0.002555645158855335)
# 66. feature #15: dsm_min_sl (0.001501838314469604)
# 67. feature #27: lcov_11_sl (0.0014487083168304147)
# 68. feature #54: pdens_min (0.0003425420439789356)
# 69. feature #49: ntl_min_sl (0.0)
# 70. feature #47: ntl_mean_sl (0.0)
# 71. feature #46: ntl_mean (0.0)
# 72. feature #45: ntl_max_sl (0.0)
# 73. feature #44: ntl_max (0.0)
# 74. feature #48: ntl_min (0.0)

# %%
important_num = 5 # top five
importances = gbm_day_reg.feature_importances_
covariates = X_train.columns

indices = np.argsort(importances)[::-1]

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importance: Day")
plt.bar(range(important_num), importances[indices[0:important_num]],
       color="r", align="center")
plt.xticks(range(important_num), covariates[indices[0:important_num]], rotation=90)
plt.xlim([-1, important_num])
plt.show()

# Print the feature ranking
print("Feature ranking:")

for f in range(len(indices)): 
    print("{}. feature #{}: {} ({})".format(f + 1,indices[f], covariates[indices[f]], importances[indices[f]]))
# Out:
# Feature ranking:
# 1. feature #2: alb_mean (0.045337687202379226)
# 2. feature #34: nbdi_sd (0.03704921436441487)
# 3. feature #30: nbdi_mean (0.03314626368166148)
# 4. feature #4: alb_min (0.032961586048695125)
# 5. feature #43: ndvi_sd_sl (0.03128276287769438)
# 6. feature #68: tree_mean (0.028720835288957806)
# 7. feature #72: tree_sd (0.027103841449136017)
# 8. feature #40: ndvi_min (0.026988722260717506)
# 9. feature #32: nbdi_min (0.02697836799509509)
# 10. feature #9: bldg_sl (0.0257865701251025)
# 11. feature #8: bldg (0.02482951867458047)
# 12. feature #10: dsm_max (0.02393305266057871)
# 13. feature #53: pdens_mean_sl (0.023342572983765592)
# 14. feature #25: elev_sd_sl (0.02193857523743367)
# 15. feature #6: alb_sd (0.021872202857668208)
# 16. feature #38: ndvi_mean (0.02131098518171434)
# 17. feature #36: ndvi_max (0.020964050090763645)
# 18. feature #64: svf_sd (0.02041799102103611)
# 19. feature #0: alb_max (0.020343430445328232)
# 20. feature #35: nbdi_sd_sl (0.019493928525270703)
# 21. feature #28: nbdi_max (0.01929903812259779)
# 22. feature #69: tree_mean_sl (0.01914309188442743)
# 23. feature #11: dsm_max_sl (0.01818751740757971)
# 24. feature #58: svf_max (0.018106706200616274)
# 25. feature #56: pdens_sd (0.017292572547550088)
# 26. feature #61: svf_mean_sl (0.016450824953617514)
# 27. feature #73: tree_sd_sl (0.01590760042308791)
# 28. feature #60: svf_mean (0.014947660953416125)
# 29. feature #59: svf_max_sl (0.01440115203799251)
# 30. feature #23: elev_min_sl (0.0139522928426924)
# 31. feature #16: dsm_sd (0.01387656657583611)
# 32. feature #29: nbdi_max_sl (0.01377535503277177)
# 33. feature #18: elev_max (0.01306913998346725)
# 34. feature #31: nbdi_mean_sl (0.012501870514901368)
# 35. feature #33: nbdi_min_sl (0.012365806448104224)
# 36. feature #42: ndvi_sd (0.011724922247248207)
# 37. feature #67: tree_max_sl (0.011609008526991748)
# 38. feature #7: alb_sd_sl (0.011564971294101764)
# 39. feature #41: ndvi_min_sl (0.011093988793896437)
# 40. feature #63: svf_min_sl (0.01100922043091219)
# 41. feature #52: pdens_mean (0.010934252389765782)
# 42. feature #24: elev_sd (0.010892871189718956)
# 43. feature #65: svf_sd_sl (0.010571927845330887)
# 44. feature #51: pdens_max_sl (0.010287806871078735)
# 45. feature #37: ndvi_max_sl (0.009847721389585026)
# 46. feature #55: pdens_min_sl (0.009308203940730187)
# 47. feature #1: alb_max_sl (0.00918377162605943)
# 48. feature #62: svf_min (0.008904929732489577)
# 49. feature #12: dsm_mean (0.008803351763568662)
# 50. feature #5: alb_min_sl (0.008663624059229342)
# 51. feature #26: lcov_11 (0.00823982268213813)
# 52. feature #57: pdens_sd_sl (0.00735281522021938)
# 53. feature #50: pdens_max (0.006979504916206778)
# 54. feature #22: elev_min (0.0062364356554950855)
# 55. feature #54: pdens_min (0.006053728369745046)
# 56. feature #47: ntl_mean_sl (0.005772829822688856)
# 57. feature #39: ndvi_mean_sl (0.005751416559834439)
# 58. feature #3: alb_mean_sl (0.0053179253401692056)
# 59. feature #13: dsm_mean_sl (0.00529045366071315)
# 60. feature #21: elev_mean_sl (0.003488186151530555)
# 61. feature #14: dsm_min (0.003341569402385021)
# 62. feature #17: dsm_sd_sl (0.003021330821259294)
# 63. feature #66: tree_max (0.003014845428618711)
# 64. feature #19: elev_max_sl (0.0024595098490010465)
# 65. feature #15: dsm_min_sl (0.0021210608670339413)
# 66. feature #20: elev_mean (0.001883617497477731)
# 67. feature #49: ntl_min_sl (0.0016751820764339413)
# 68. feature #71: tree_min_sl (0.0005034908810421202)
# 69. feature #27: lcov_11_sl (1.6347796648501176e-05)
# 70. feature #44: ntl_max (0.0)
# 71. feature #45: ntl_max_sl (0.0)
# 72. feature #46: ntl_mean (0.0)
# 73. feature #48: ntl_min (0.0)
# 74. feature #70: tree_min (0.0)

# %% [markdown]
# Note:
# * lcov_11 is the area of water in the grid cell
# * lcov_22 is low-intensity development. usually 20-49% impervious surface, with single-family housing.

# %% [markdown]
# ### Partial Dependence

# %%
pdp_day = partial_dependence(gbm_day_reg, [1], X=X_train) 
pdp_night = partial_dependence(gbm_night_reg, [1], X=X_train) 
# plt.plot(pdp_day[0], pdp_day[1], pdp_night[0], pdp_night[1])
# %matplotlib inline
plt.plot(pdp_night[1][0], pdp_night[0][0], label = 'night')
plt.plot(pdp_day[1][0], pdp_day[0][0], label = 'day')
plt.ylabel('Change in $^o$C')
plt.xlabel('Mean Albedo')
plt.legend(loc='upper right')
plt.show()

# %%
pdp_day = partial_dependence(gbm_day_reg, [4], X=X_train) 
pdp_night = partial_dependence(gbm_night_reg, [4], X=X_train) 
# plt.plot(pdp_day[0], pdp_day[1], pdp_night[0], pdp_night[1])
# %matplotlib inline
plt.plot(pdp_night[1][0], pdp_night[0][0], label = 'night')
plt.plot(pdp_day[1][0], pdp_day[0][0], label = 'day')
plt.ylabel('Change in $^o$C')
plt.xlabel('Mean NDVI')
plt.legend(loc='upper right')
plt.show()

# %%
pdp_day = partial_dependence(gbm_day_reg, [7], X=X_train) 
pdp_night = partial_dependence(gbm_night_reg, [7], X=X_train) 
# plt.plot(pdp_day[0], pdp_day[1], pdp_night[0], pdp_night[1])
# %matplotlib inline
plt.plot(pdp_night[1][0], pdp_night[0][0], label = 'night')
plt.plot(pdp_day[1][0], pdp_day[0][0], label = 'day')
plt.ylabel('Change in $^o$C')
plt.xlabel('Area of water')
plt.legend(loc='upper right')
plt.show()

# %%
pdp_day = partial_dependence(gbm_day_reg, [20], X=X_train) 
pdp_night = partial_dependence(gbm_night_reg, [20], X=X_train) 
# plt.plot(pdp_day[0], pdp_day[1], pdp_night[0], pdp_night[1])
# %matplotlib inline
plt.plot(pdp_night[1][0], pdp_night[0][0], label = 'night')
plt.plot(pdp_day[1][0], pdp_day[0][0], label = 'day')
plt.ylabel('Change in $^o$C')
plt.xlabel('Tree canopy')
plt.legend(loc='upper right')
plt.show()

# %%
pdp_day = partial_dependence(gbm_day_reg, [23], X=X_train) 
pdp_night = partial_dependence(gbm_night_reg, [23], X=X_train) 
# plt.plot(pdp_day[0], pdp_day[1], pdp_night[0], pdp_night[1])
# %matplotlib inline
plt.plot(pdp_night[1][0], pdp_night[0][0], label = 'night')
plt.plot(pdp_day[1][0], pdp_day[0][0], label = 'day')
plt.ylabel('Change in $^o$C')
plt.xlabel('Impervious surface')
plt.legend(loc='upper right')
plt.show()
