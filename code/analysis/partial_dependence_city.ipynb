# %%
import os 
dir_primary = 'F:/UrbanDataProject/land_surface_temperature/code/analysis'
# os.chdir('/home/tml/research/land_surface_temperature/code/analysis')
os.chdir(dir_primary)
from analysis import *
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.ensemble.partial_dependence import plot_partial_dependence
import os
import glob
code_dir = os.getcwd()
os.chdir('../..')

# %% [markdown]
# # Import data

# %%
cities = ['bal', 'por', 'det', 'phx']
# import data
grid_size = 500
df = import_data(grid_size)

# %% [markdown]
# # City Partial Dependence

# %%
calculate_partial_dependence_city(df, grid_size, cities)
# Out:
# lst_day_mean
# lst_night_mean
# lst_night_max
# lst_day_max
# lst_day_mean
# lst_night_mean
# lst_night_max
# lst_day_max
# lst_day_mean
# lst_night_mean
# lst_night_max
# lst_day_max
# lst_day_mean
# lst_night_mean
# lst_night_max
# lst_day_max

# %%
plot_dependence_city(grid_size)
# Out:
# f:\urbandataproject\land_surface_temperature\venv\lib\site-packages\matplotlib\figure.py:2369: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# f:\urbandataproject\land_surface_temperature\venv\lib\site-packages\matplotlib\figure.py:2369: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# f:\urbandataproject\land_surface_temperature\venv\lib\site-packages\matplotlib\figure.py:2369: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# f:\urbandataproject\land_surface_temperature\venv\lib\site-packages\matplotlib\figure.py:2369: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
